# %%
# for installing XgBoost
import sys
print(sys.executable)
# Out:
# c:\Users\sahak\anaconda3\python.exe

# %%
import sys
# !{sys.executable} -m pip install xgboost
# Out:
# ...
#    ---------------------------------------- 0.0/48.9 MB ? eta -:--:--
#    ---------------------------------------- 0.5/48.9 MB 3.6 MB/s eta 0:00:14
#    - -------------------------------------- 1.3/48.9 MB 4.2 MB/s eta 0:00:12
#    -- ------------------------------------- 2.6/48.9 MB 4.7 MB/s eta 0:00:10
#    --- ------------------------------------ 3.9/48.9 MB 5.2 MB/s eta 0:00:09
#    ---- ----------------------------------- 5.2/48.9 MB 5.7 MB/s eta 0:00:08
#    ---- ----------------------------------- 6.0/48.9 MB 5.2 MB/s eta 0:00:09
#    ----- ---------------------------------- 6.6/48.9 MB 4.8 MB/s eta 0:00:09
#    ----- ---------------------------------- 6.8/48.9 MB 4.3 MB/s eta 0:00:10
#    ----- ---------------------------------- 7.1/48.9 MB 4.0 MB/s eta 0:00:11
#    ----- ---------------------------------- 7.3/48.9 MB 3.7 MB/s eta 0:00:12
#    ------ --------------------------------- 7.6/48.9 MB 3.5 MB/s eta 0:00:12
# ...

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\sahak\Desktop\DemandForecasting
